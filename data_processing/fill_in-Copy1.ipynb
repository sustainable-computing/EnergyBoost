# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
hh_df = pd.read_csv('home_ac/processed_hhdata_86_2.csv')[1990:2020]
# print(hh_df.shape)
# hh_df.head(15)
hh_df.drop_duplicates(subset ="localhour", keep = False, inplace = True)
print(hh_df.shape)
# Out:
# (30, 10)

# %%
hh_df['hour_index']=0
#hh_df.iloc[-50]

# %%
used = ['localhour', 'use', 'temperature', 'cloud_cover','GH', 'is_weekday','month','hour','AC','hour_index']
datarow= []

# %%
hour_index=0#hour index
hour_value=0
missing_count=0
for index, row in hh_df.iterrows():
    row.localhour=row.localhour[:-3]
    #print(row.localhour)
    difference=(pd.to_datetime(row.localhour)-pd.to_datetime(hh_df['localhour'].iloc[0][:-3])).total_seconds()/3600
    #print("index is difference",difference)
    
    if difference!=hour_index:
        gap = difference-hour_index
        missing_count += gap
        #fill in the missing hours
        for i in range(int(gap)):
            print("missing data for hour index:",hour_index+i)
            row.hour=(hour_index+i)%24
            row.hour_index=hour_index+i
            datarow.append(row[used])
            
        hour_index = difference
    hour_index +=1
    row.hour_index=difference
    #hour_value = row.hour
    #print(row[used])
    datarow.append(row[used])
print("total missing hours",missing_count)




    
       
#------------------------------------------testing----------------------------
# hour_index=0 #hour index
# missing_count=0
# for index, row in hh_df.iterrows():
#     #print(row.localhour)
#     #row.month = float(pd.to_datetime(row.localhour[:-3]).month)
#     #row.day = float(pd.to_datetime(row.localhour[:-3]).day)
#     #data_hour = float(pd.to_datetime(row.localhour).hour-6)%24
#     data_hour = float(pd.to_datetime(row.localhour[:-3]).hour)
#     #print(data_hour)
#     if data_hour != hour_index%24:
#         print("we are missing hours for",row.localhour)
#         missing_count += 1
#         hour_index +=1
#     hour_index += 1
# print("In total missing hours", missing_count)

# for index, row in hh_df.iterrows():
#     #row.month = float(pd.to_datetime(row.localhour[:-3]).month)
#     #row.day = float(pd.to_datetime(row.localhour[:-3]).day)
#     print("------------")
#     print(row.localhour)
#     print(float(pd.to_datetime(row.localhour).hour-6)%24)
#     print(float(pd.to_datetime(row.localhour[:-3]).hour))
# #     print(pd.to_datetime(row.localhour))
# #     print(pd.to_datetime(row.localhour).tz_localize('UTC'))
# #     print(pd.to_datetime(row.localhour).tz_localize('UTC').tz_convert('US/Central'))
# #     print(pd.to_datetime(row.localhour[:-3]).tz_localize('US/Central'))
# #     print(pd.to_datetime(row.localhour)-pd.Timedelta('06:00:00'))
# Out:
# missing data for hour index: 1
# temprow before insert localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       1
# Name: 1990, dtype: object
# [localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       0
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       1
# Name: 1990, dtype: object]
# missing data for hour index: 2
# temprow before insert localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       2
# Name: 1990, dtype: object
# [localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       0
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       2
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       2
# Name: 1990, dtype: object]
# missing data for hour index: 3
# temprow before insert localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       3
# Name: 1990, dtype: object
# [localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       0
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       3
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       3
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       3
# Name: 1990, dtype: object]
# missing data for hour index: 4
# temprow before insert localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       4
# Name: 1990, dtype: object
# [localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       0
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       4
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       4
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       4
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       4
# Name: 1990, dtype: object]
# missing data for hour index: 5
# temprow before insert localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       5
# Name: 1990, dtype: object
# [localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       0
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       5
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       5
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       5
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       5
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       5
# Name: 1990, dtype: object]
# missing data for hour index: 6
# temprow before insert localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       6
# Name: 1990, dtype: object
# [localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       0
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       6
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       6
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       6
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       6
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       6
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       6
# Name: 1990, dtype: object]
# missing data for hour index: 7
# temprow before insert localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       7
# Name: 1990, dtype: object
# [localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       0
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       7
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       7
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       7
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       7
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       7
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       7
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       7
# Name: 1990, dtype: object]
# missing data for hour index: 8
# temprow before insert localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       8
# Name: 1990, dtype: object
# [localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       0
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       8
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       8
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       8
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       8
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       8
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       8
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       8
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       8
# Name: 1990, dtype: object]
# missing data for hour index: 9
# temprow before insert localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       9
# Name: 1990, dtype: object
# [localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       0
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       9
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       9
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       9
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       9
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       9
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       9
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       9
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       9
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       9
# Name: 1990, dtype: object]
# missing data for hour index: 10
# temprow before insert localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      10
# Name: 1990, dtype: object
# [localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       0
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      10
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      10
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      10
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      10
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      10
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      10
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      10
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      10
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      10
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      10
# Name: 1990, dtype: object]
# missing data for hour index: 11
# temprow before insert localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      11
# Name: 1990, dtype: object
# [localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       0
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      11
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      11
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      11
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      11
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      11
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      11
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      11
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      11
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      11
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      11
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      11
# Name: 1990, dtype: object]
# missing data for hour index: 12
# temprow before insert localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      12
# Name: 1990, dtype: object
# [localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       0
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      12
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      12
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      12
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      12
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      12
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      12
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      12
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      12
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      12
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      12
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      12
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      12
# Name: 1990, dtype: object]
# missing data for hour index: 13
# temprow before insert localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      13
# Name: 1990, dtype: object
# [localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       0
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      13
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      13
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      13
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      13
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      13
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      13
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      13
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      13
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      13
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      13
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      13
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      13
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      13
# Name: 1990, dtype: object]
# missing data for hour index: 14
# temprow before insert localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      14
# Name: 1990, dtype: object
# [localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                       0
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      14
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      14
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      14
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      14
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      14
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# cloud_cover                   0.99
# GH                        -2.71949
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      14
# Name: 1990, dtype: object, localhour      2016-03-23 23:00:00
# use                       0.465617
# temperature                  69.18
# ...
# hour                             5
# AC                               0
# hour_index                      30
# Name: 1996, dtype: object, localhour      2016-03-25 06:00:00
# use                       0.439383
# temperature                  42.93
# cloud_cover                   0.04
# GH                        -3.06337
# is_weekday                       1
# month                            3
# hour                             6
# AC                               0
# hour_index                      31
# Name: 1997, dtype: object, localhour      2016-03-25 07:00:00
# use                        3.23617
# temperature                  42.51
# cloud_cover                   0.04
# GH                         44.9332
# is_weekday                       1
# month                            3
# hour                             7
# AC                               0
# hour_index                      32
# Name: 1998, dtype: object, localhour      2016-03-25 08:00:00
# use                        1.25295
# temperature                  44.18
# cloud_cover                   0.13
# GH                         293.449
# is_weekday                       1
# month                            3
# hour                             8
# AC                         1.01182
# hour_index                      33
# Name: 1999, dtype: object, localhour      2016-03-25 09:00:00
# use                         1.3172
# temperature                  50.45
# cloud_cover                   0.18
# GH                         529.385
# is_weekday                       1
# month                            3
# hour                             9
# AC                         1.86052
# hour_index                      34
# Name: 2000, dtype: object, localhour      2016-03-25 10:00:00
# use                        1.55068
# temperature                  56.59
# cloud_cover                   0.16
# GH                         557.805
# is_weekday                       1
# month                            3
# hour                            10
# AC                          2.1779
# hour_index                      35
# Name: 2001, dtype: object, localhour      2016-03-25 11:00:00
# use                        1.88443
# temperature                  60.04
# cloud_cover                   0.13
# GH                         875.311
# is_weekday                       1
# month                            3
# hour                            11
# AC                         3.41005
# hour_index                      36
# Name: 2002, dtype: object, localhour      2016-03-25 12:00:00
# use                        2.01053
# temperature                  63.38
# cloud_cover                    0.1
# GH                         988.654
# is_weekday                       1
# month                            3
# hour                            12
# AC                          3.8706
# hour_index                      37
# Name: 2003, dtype: object, localhour      2016-03-25 13:00:00
# use                        2.03128
# temperature                  66.62
# cloud_cover                   0.04
# GH                         946.381
# is_weekday                       1
# month                            3
# hour                            13
# AC                         3.71165
# hour_index                      38
# Name: 2004, dtype: object, localhour      2016-03-25 14:00:00
# use                        1.76995
# temperature                   68.9
# cloud_cover                   0.04
# GH                         925.627
# is_weekday                       1
# month                            3
# hour                            14
# AC                          3.5799
# hour_index                      39
# Name: 2005, dtype: object, localhour      2016-03-25 15:00:00
# use                         0.9173
# temperature                   70.9
# cloud_cover                   0.04
# GH                         596.739
# is_weekday                       1
# month                            3
# hour                            15
# AC                         2.06293
# hour_index                      40
# Name: 2006, dtype: object, localhour      2016-03-25 16:00:00
# use                       0.743667
# temperature                  71.55
# cloud_cover                   0.06
# GH                          517.91
# is_weekday                       1
# month                            3
# hour                            16
# AC                         1.79614
# hour_index                      41
# Name: 2007, dtype: object, localhour      2016-03-25 17:00:00
# use                         0.7725
# temperature                  72.11
# cloud_cover                   0.15
# GH                         368.775
# is_weekday                       1
# month                            3
# hour                            17
# AC                         1.24241
# hour_index                      42
# Name: 2008, dtype: object, localhour      2016-03-25 18:00:00
# use                       0.914833
# temperature                  71.51
# cloud_cover                   0.17
# GH                         76.5365
# is_weekday                       1
# month                            3
# hour                            18
# AC                        0.186925
# hour_index                      43
# Name: 2009, dtype: object, localhour      2016-03-25 19:00:00
# use                        1.14068
# temperature                  68.43
# cloud_cover                   0.18
# GH                        -2.71889
# is_weekday                       1
# month                            3
# hour                            19
# AC                               0
# hour_index                      44
# Name: 2010, dtype: object, localhour      2016-03-25 20:00:00
# use                        1.18023
# temperature                  64.35
# cloud_cover                   0.03
# GH                        -2.71957
# is_weekday                       1
# month                            3
# hour                            20
# AC                               0
# hour_index                      45
# Name: 2011, dtype: object, localhour      2016-03-25 21:00:00
# use                        1.11133
# temperature                  61.22
# cloud_cover                   0.01
# GH                        -2.72041
# is_weekday                       1
# month                            3
# hour                            21
# AC                               0
# hour_index                      46
# Name: 2012, dtype: object, localhour      2016-03-25 22:00:00
# use                       0.569667
# temperature                  58.91
# cloud_cover                      0
# GH                        -2.72055
# is_weekday                       1
# month                            3
# hour                            22
# AC                               0
# hour_index                      47
# Name: 2013, dtype: object, localhour      2016-03-25 23:00:00
# use                       0.279933
# temperature                  58.02
# cloud_cover                   0.01
# GH                        -2.72109
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      48
# Name: 2014, dtype: object, localhour      2016-03-25 23:00:00
# use                       0.279933
# temperature                  58.02
# cloud_cover                   0.01
# GH                        -2.72109
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      72
# Name: 2014, dtype: object, localhour      2016-03-25 23:00:00
# use                       0.279933
# temperature                  58.02
# cloud_cover                   0.01
# GH                        -2.72109
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      72
# Name: 2014, dtype: object, localhour      2016-03-25 23:00:00
# use                       0.279933
# temperature                  58.02
# cloud_cover                   0.01
# GH                        -2.72109
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      72
# Name: 2014, dtype: object, localhour      2016-03-25 23:00:00
# use                       0.279933
# temperature                  58.02
# cloud_cover                   0.01
# GH                        -2.72109
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      72
# Name: 2014, dtype: object, localhour      2016-03-25 23:00:00
# use                       0.279933
# temperature                  58.02
# cloud_cover                   0.01
# GH                        -2.72109
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      72
# Name: 2014, dtype: object, localhour      2016-03-25 23:00:00
# use                       0.279933
# temperature                  58.02
# cloud_cover                   0.01
# GH                        -2.72109
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      72
# Name: 2014, dtype: object, localhour      2016-03-25 23:00:00
# use                       0.279933
# temperature                  58.02
# cloud_cover                   0.01
# GH                        -2.72109
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      72
# Name: 2014, dtype: object, localhour      2016-03-25 23:00:00
# use                       0.279933
# temperature                  58.02
# cloud_cover                   0.01
# GH                        -2.72109
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      72
# Name: 2014, dtype: object, localhour      2016-03-25 23:00:00
# use                       0.279933
# temperature                  58.02
# cloud_cover                   0.01
# GH                        -2.72109
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      72
# Name: 2014, dtype: object, localhour      2016-03-25 23:00:00
# use                       0.279933
# temperature                  58.02
# cloud_cover                   0.01
# GH                        -2.72109
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      72
# Name: 2014, dtype: object, localhour      2016-03-25 23:00:00
# use                       0.279933
# temperature                  58.02
# cloud_cover                   0.01
# GH                        -2.72109
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      72
# Name: 2014, dtype: object, localhour      2016-03-25 23:00:00
# use                       0.279933
# temperature                  58.02
# cloud_cover                   0.01
# GH                        -2.72109
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      72
# Name: 2014, dtype: object, localhour      2016-03-25 23:00:00
# use                       0.279933
# temperature                  58.02
# cloud_cover                   0.01
# GH                        -2.72109
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      72
# Name: 2014, dtype: object, localhour      2016-03-25 23:00:00
# use                       0.279933
# temperature                  58.02
# cloud_cover                   0.01
# GH                        -2.72109
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      72
# Name: 2014, dtype: object, localhour      2016-03-25 23:00:00
# use                       0.279933
# temperature                  58.02
# cloud_cover                   0.01
# GH                        -2.72109
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      72
# Name: 2014, dtype: object, localhour      2016-03-25 23:00:00
# use                       0.279933
# temperature                  58.02
# cloud_cover                   0.01
# GH                        -2.72109
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      72
# Name: 2014, dtype: object, localhour      2016-03-25 23:00:00
# use                       0.279933
# temperature                  58.02
# cloud_cover                   0.01
# GH                        -2.72109
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      72
# Name: 2014, dtype: object, localhour      2016-03-25 23:00:00
# use                       0.279933
# temperature                  58.02
# cloud_cover                   0.01
# GH                        -2.72109
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      72
# Name: 2014, dtype: object, localhour      2016-03-25 23:00:00
# use                       0.279933
# temperature                  58.02
# cloud_cover                   0.01
# GH                        -2.72109
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      72
# Name: 2014, dtype: object, localhour      2016-03-25 23:00:00
# use                       0.279933
# temperature                  58.02
# cloud_cover                   0.01
# GH                        -2.72109
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      72
# Name: 2014, dtype: object, localhour      2016-03-25 23:00:00
# use                       0.279933
# temperature                  58.02
# cloud_cover                   0.01
# GH                        -2.72109
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      72
# Name: 2014, dtype: object, localhour      2016-03-25 23:00:00
# use                       0.279933
# temperature                  58.02
# cloud_cover                   0.01
# GH                        -2.72109
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      72
# Name: 2014, dtype: object, localhour      2016-03-25 23:00:00
# use                       0.279933
# temperature                  58.02
# cloud_cover                   0.01
# GH                        -2.72109
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      72
# Name: 2014, dtype: object, localhour      2016-03-25 23:00:00
# use                       0.279933
# temperature                  58.02
# cloud_cover                   0.01
# GH                        -2.72109
# is_weekday                       1
# month                            3
# hour                            23
# AC                               0
# hour_index                      72
# Name: 2014, dtype: object]
# total missing hours 48.0

# %%
df = pd.DataFrame(data=datarow, columns=used)
print(df.head())
df.to_csv('datanew/afterfix6.csv')
# Out:
#                 localhour       use  temperature  cloud_cover       GH  \
# 1990  2016-03-23 23:00:00  0.465617        69.18         0.99 -2.71949
# 1990  2016-03-23 23:00:00  0.465617        69.18         0.99 -2.71949
# 1990  2016-03-23 23:00:00  0.465617        69.18         0.99 -2.71949
# 1990  2016-03-23 23:00:00  0.465617        69.18         0.99 -2.71949
# 1990  2016-03-23 23:00:00  0.465617        69.18         0.99 -2.71949
#
#       is_weekday  month  hour   AC  hour_index
# 1990           1      3    23  0.0         0.0
# 1990           1      3    23  0.0        24.0
# 1990           1      3    23  0.0        24.0
# 1990           1      3    23  0.0        24.0
# 1990           1      3    23  0.0        24.0

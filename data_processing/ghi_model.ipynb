# %%
import numpy as np
import pandas as pd
import glob
from sklearn.externals import joblib

from sklearn import ensemble

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

# %%
#hhids=[26, 59, 77, 86, 93, 94, 101, 114, 115, 160, 171, 187, 222, 252, 370, 379, 410, 434, 483, 484, 499, 503, 545, 575, 580, 585, 621, 624, 661, 668, 739, 744, 781, 796, 871, 890, 898, 930, 936, 946, 974, 994, 1086, 1103, 1169, 1185, 1192, 1202, 1283, 1310, 1314, 1334, 1354, 1403, 1415, 1463, 1500, 1507, 1551, 1589, 1617, 1632, 1642, 1681, 1697, 1700, 1714, 1718, 1790, 1791, 1792, 1796, 1800, 1801, 1947, 1953, 2004, 2018, 2034, 2072, 2094, 2129, 2156, 2158, 2171, 2199, 2204, 2233, 2242, 2335, 2337, 2361, 2365, 2378, 2401, 2449, 2461, 2470, 2472, 2510, 2532, 2557, 2575, 2638, 2641, 2742, 2750, 2755, 2769, 2787, 2814, 2818, 2829, 2859, 2925, 2945, 2953, 2965, 2980, 2986]


for filename in glob.glob('data_added2/added_hhdata_*'):
    basename=filename.split("/")[1].split(".")[0]
    hhid=basename.split("_")[2]
    #result[hhid] = []
    print('Start :: Process on household {}...'.format(hhid))
    df = pd.read_csv('data_added2/added_hhdata_{}_2.csv'.format(hhid), index_col=0)
    st = []
    ct = 0
    for idx, row in df.iterrows():
        if row.GH < 2000 and row.GH > -1000:
            st.append(row)
        else:
            ct += 1

    # print(ct)
    df = pd.DataFrame(data=st, columns=df.columns)
    features = ['use', 'temperature', 'cloud_cover','wind_speed','is_weekday','ac_hour','ac_week','month','hour']



    Y = list(df.ac)[1:]
    Y.append(df.ac.iloc[0])
    Y = np.array(Y)

    X = df[features]
    X = np.array(X)
    X.shape

    temp_df = pd.DataFrame(data=X, columns=features)
    temp_df['y_GH'] = Y
    values = temp_df.values

    # normalize features
    scaler = MinMaxScaler()
    y_gt = values[:,-1:]
    scaled = scaler.fit_transform(values)
    values = scaled

    X_train, X_test, Y_train, Y_test = train_test_split(X, Y,
                                                        test_size=0.10,
                                                        random_state=666)


    clf = ensemble.RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
           max_features='sqrt', max_leaf_nodes=None,
           min_impurity_decrease=0.0, min_impurity_split=None,
           min_samples_leaf=1, min_samples_split=2,
           min_weight_fraction_leaf=0.0, n_estimators=75, n_jobs=1,
           oob_score=False, random_state=0, verbose=0, warm_start=False)

    clf.fit(X_train, Y_train)
    yhat = clf.predict(X_test)
    rmse = np.sqrt(mean_squared_error(Y_test, yhat))
    mae = mean_absolute_error(Y_test, yhat)
    print('RMSE =>', rmse)
    print('MAE =>', mae)
    joblib.dump(clf, 'saved_models/ghi_rf_{}.pkl'.format(hhid))
# Out:
# Start :: Process on household 1801...
# RMSE => 0.5615728973358283
# MAE => 0.28776945588026326
# Start :: Process on household 2401...
# RMSE => 0.5561046444511705
# MAE => 0.28606486453286545
# Start :: Process on household 871...
# RMSE => 0.5513650221786801
# MAE => 0.2815750706872321
# Start :: Process on household 1700...
# RMSE => 0.5527128793347976
# MAE => 0.28567656483609516
# Start :: Process on household 2818...
# RMSE => 0.5614048323555907
# MAE => 0.2903534067356841
# Start :: Process on household 2980...
# RMSE => 0.5569542788827471
# MAE => 0.2876651998782086
# Start :: Process on household 2378...
# RMSE => 0.5627430303586806
# MAE => 0.28777633334638447
# Start :: Process on household 503...
# RMSE => 0.5506090066170709
# MAE => 0.28329461684094476
# Start :: Process on household 2787...
# RMSE => 0.5616688816074775
# MAE => 0.28986095485980223
# Start :: Process on household 434...
# RMSE => 0.55948317980182
# MAE => 0.285894665328006
# Start :: Process on household 890...
# RMSE => 0.5602822939175692
# MAE => 0.28811600456573305
# Start :: Process on household 93...
# RMSE => 0.5628913827141004
# MAE => 0.29069683484401093
# Start :: Process on household 2532...
# RMSE => 0.5638841006230998
# MAE => 0.29033629620904355
# Start :: Process on household 114...
# RMSE => 0.5547940921657284
# MAE => 0.28403285553081675
# Start :: Process on household 1792...
# RMSE => 0.5532187208153153
# MAE => 0.2850577679665248
# Start :: Process on household 2925...
# RMSE => 0.5492661744378461
# MAE => 0.2806517648354515
# Start :: Process on household 545...
# RMSE => 0.5580680454249052
# MAE => 0.2859659668415399
# Start :: Process on household 2337...
# RMSE => 0.5485843016428464
# MAE => 0.2847073558188145
# Start :: Process on household 1507...
# RMSE => 0.5560919969483202
# MAE => 0.28550161082123215
# Start :: Process on household 2755...
# RMSE => 0.5513418857153156
# MAE => 0.2880420310366657
# Start :: Process on household 2945...
# RMSE => 0.5566516241882578
# MAE => 0.2888830706250087
# Start :: Process on household 2365...
# RMSE => 0.560985516325077
# MAE => 0.2867965766712426
# Start :: Process on household 585...
# RMSE => 0.5667604349035794
# MAE => 0.292957917998368
# Start :: Process on household 2953...
# RMSE => 0.5605399259143125
# MAE => 0.2870567762652708
# Start :: Process on household 1403...
# RMSE => 0.5683488177000137
# MAE => 0.2911309321598266
# Start :: Process on household 26...
# RMSE => 0.5511628924546889
# MAE => 0.2820624503937165
# Start :: Process on household 370...
# RMSE => 0.5550049521733209
# MAE => 0.28424768884358137
# Start :: Process on household 1283...
# RMSE => 0.5584601287210825
# MAE => 0.28749194008237305
# Start :: Process on household 187...
# RMSE => 0.5531630256665442
# MAE => 0.28499458036425507
# Start :: Process on household 974...
# RMSE => 0.5683831019100113
# MAE => 0.2908448469528623
# Start :: Process on household 2233...
# RMSE => 0.5567159196392338
# MAE => 0.2857171832707975
# Start :: Process on household 624...
# RMSE => 0.5512231124945521
# MAE => 0.2848805549040469
# Start :: Process on household 2472...
# RMSE => 0.5647141936066666
# MAE => 0.2881233809845126
# Start :: Process on household 499...
# RMSE => 0.5616174987044701
# MAE => 0.29100531658270257
# Start :: Process on household 2018...
# RMSE => 0.5515268600082738
# MAE => 0.28153116380532933
# Start :: Process on household 101...
# RMSE => 0.5628523308205434
# MAE => 0.2876556459662424
# Start :: Process on household 2575...
# RMSE => 0.5614122241629641
# MAE => 0.28891314203986024
# Start :: Process on household 2829...
# RMSE => 0.5492155783286959
# MAE => 0.2820440160321889
# Start :: Process on household 1202...
# RMSE => 0.5590593288595467
# MAE => 0.28299754542469296
# Start :: Process on household 77...
# RMSE => 0.5600673587346003
# MAE => 0.2881940890423862
# Start :: Process on household 1500...
# RMSE => 0.5585824043274034
# MAE => 0.2876212510105656
# Start :: Process on household 1463...
# RMSE => 0.5530801407637853
# MAE => 0.2853530000472449
# Start :: Process on household 379...
# RMSE => 0.5517163775820917
# MAE => 0.28338439217378286
# Start :: Process on household 59...
# RMSE => 0.5696515112281882
# MAE => 0.2925241092855909
# Start :: Process on household 1103...
# RMSE => 0.5485639858152787
# MAE => 0.2808637380233041
# Start :: Process on household 2557...
# RMSE => 0.5507639950725172
# MAE => 0.28659837901065766
# Start :: Process on household 2986...
# RMSE => 0.5520489974059779
# MAE => 0.28194506327954305
# Start :: Process on household 1697...
# RMSE => 0.5555858765554629
# MAE => 0.2848105845745784
# Start :: Process on household 1642...
# RMSE => 0.5532014940257102
# MAE => 0.2837957134911448
# Start :: Process on household 86...
# RMSE => 0.557823223327343
# MAE => 0.285535938407207
# Start :: Process on household 1169...
# RMSE => 0.5642102759943086
# MAE => 0.2898552988531655
# Start :: Process on household 744...
# RMSE => 0.5536147820360061
# MAE => 0.2824472050974738
# Start :: Process on household 1800...
# RMSE => 0.5546723699515312
# MAE => 0.2895716494058291
# Start :: Process on household 1714...
# RMSE => 0.5672876446234607
# MAE => 0.28850918412801374
# Start :: Process on household 94...
# RMSE => 0.545935505766203
# MAE => 0.27771984066381805
# Start :: Process on household 2814...
# RMSE => 0.557078162186069
# MAE => 0.2846892388464488
# Start :: Process on household 1790...
# RMSE => 0.5680537590326018
# MAE => 0.29304411925113605
# Start :: Process on household 2859...
# RMSE => 0.5605259194689823
# MAE => 0.2890108740979207
# Start :: Process on household 2072...
# RMSE => 0.5558848268899854
# MAE => 0.28512343307442045
# Start :: Process on household 484...
# RMSE => 0.5724551568187514
# MAE => 0.2940721157119967
# Start :: Process on household 1415...
# RMSE => 0.5589340047425936
# MAE => 0.2872539039130916
# Start :: Process on household 1632...
# RMSE => 0.5625675318324311
# MAE => 0.28827284567693995
# Start :: Process on household 252...
# RMSE => 0.5569894119369373
# MAE => 0.284147555609797
# Start :: Process on household 1086...
# RMSE => 0.5498586054097957
# MAE => 0.28107162212187403
# Start :: Process on household 1718...
# RMSE => 0.5501894548783959
# MAE => 0.28448199050827583
# Start :: Process on household 946...
# RMSE => 0.5599710687814591
# MAE => 0.28538900576367715
# Start :: Process on household 2965...
# RMSE => 0.5526624145920136
# MAE => 0.28479569397841453
# Start :: Process on household 171...
# RMSE => 0.5605374246903386
# MAE => 0.28604877017332075
# Start :: Process on household 1953...
# RMSE => 0.5642001004795965
# MAE => 0.2918737086887619
# Start :: Process on household 1192...
# RMSE => 0.5641952584956857
# MAE => 0.28998080848191343

# %%
new_clf = joblib.load('saved_models/ghi_rf_26.pkl')

# %%
X_train[0:2]
# Out:
# array([[7.3775e-01, 7.7880e+01, 6.1000e-01, 7.8000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 7.0000e+00, 5.0000e+00],
#        [1.1816e+00, 7.3900e+01, 5.0000e-02, 4.1000e+00, 1.0000e+00,
#         0.0000e+00, 0.0000e+00, 1.0000e+01, 1.0000e+00]])

# %%
new_clf.predict(X_train[0:2])
# Out:
# array([0.00794729, 0.        ])

# %%
Y_train[0:2]
# Out:
# array([0., 0.])
